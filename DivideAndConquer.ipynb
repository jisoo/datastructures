# %% [markdown]
# # 1. Algorithms

# %% [markdown]
# 1. Binary Search
# 2. Quicksort
# 3. Merge sort
# 4. Closest Pair Points
# 5. Strassen's Algorithm
# 6. Cooley-Turkey Fast Fourier Transform
# 7. Karatsuba algorithm

# %% [markdown]
# **Divide**: This involves dividing the problem into some sub problem.\
# **Conquer**: Sub problem by calling recursively until sub problem solved.\
# **Combine**: The Sub problem Solved so that we will get find problem solution.

# %% [markdown]
# Divide and Conquer should be used when same subproblems are not evaluated many times. Otherwise Dynamic Programming or Memoization should be used. For example, Binary Search is a Divide and Conquer algorithm, we never evaluate the same subproblems again. On the other hand, for calculating nth Fibonacci number, Dynamic Programming should be preferred (See this for details).

# %% [markdown]
# # 2. Pseudo Algorithm

# %% [markdown]
# ![Screen%20Shot%202020-08-16%20at%203.10.12%20PM.png](attachment:Screen%20Shot%202020-08-16%20at%203.10.12%20PM.png)

# %% [markdown]
# ## Complexity
#
# O(1) if n is small\
# T(n) = f1(n) + 2T(n/2) + f2(n)
